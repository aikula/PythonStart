# %% [markdown]
# **Markdown** (произносится маркда́ун) — облегчённый язык разметки текста, созданный с целью обозначения форматирования в простом тексте, с максимальным сохранением его читаемости человеком, и пригодный для машинного преобразования в языки для продвинутых публикаций (HTML, Rich Text и других).
#
# Нам он позволит оформлять в блокнотах любые документы:
# - документацию
# - инструкции
# - аналитические записки, которые легко обновлять и сочетать с кодом и графиками
# - и тд.
#
# # Основы языка форматирования текста Markdown
#
# Если в верхней строчке меню выбрать из выпадающего списка вместо типа ячейки `Code` тип `Markdown`, то мы получим возможность гибко оформлять текст.
#
# ! ___Внимание___: между абзацами должна быть пустая строка, иначе текст будет сливаться в один абзац.
#
# !**Внимание**: Не забывайте менять тип ячейки с "Код" на "Markdown".
# ![TypeCell.png](attachment:TypeCell.png)

# %% [markdown]
# Если вы используете знак `#` и обязательно пробел, то мы получим заголовки разных уровней. Чем больше знаков решетка, тем ниже уровень.
#
# # Заголовок 1
#
# ## Заголовок 2
#
# ### Заголовок 3
#
# ###### Заголовок 6

# %% [markdown]
# ## Выделение текста
#
# Мы можем выделять текст используя символ `*`. Одна звездочка сделает текст *курсивом*, две звездочки - **жирным**.
#
# Если использовать символ `~` в конце и начала слова, ~получим зачеркнутый текст~.

# %% [markdown]
# ## Списки
#
# Полезная функция - создание списков. Для разметки неупорядоченных списков можно использовать или `*`, или `-`, или `+`:
#
# Для разметки неупорядоченных списков можно использовать или `*`, или `-`, или `+`:
#
# - элемент 1
# - элемент 2
# - элемент ...
#
# Вложенные пункты создаются четырьмя пробелами перед маркером пункта:
#
# * элемент 1
# * элемент 2
#     * вложенный элемент 2.1
#     * вложенный элемент 2.2
#
#     Внутри пунктов списка можно вставить абзацы с таким же отступом. Обратите внимание на пустую строку выше и на пробелы в начале (нужен по меньшей мере один, но здесь мы добавили три, чтобы также выровнять необработанный Markdown).
# * элемент ...
#
# Упорядоченный список:
#
# 1. элемент 1
# 2. элемент 2
#     1. вложенный
#     2. вложенный
# 3. элемент 3
#
# Не принципиально как пронумерованы элементы списка, интерпретатор сам правильно расставит нумерацию.

# %% [markdown]
# Иногда нужно выделить текст и мы будем использовать символ `>` с пробелом в начале строки.
#
# > Это цитата
# > Продолжение цитаты
# >> А это вложенная цитата
# >>> Еще одно вложение

# %% [markdown]
# Код мы можем отмечать в строке используя апостроф (символ на той же клавише, что и буква Ё). Например, `print('Привет, мир!')`. Или стразу три апострофа, если хотим указать целый блок. После апострофа можем указать название интерпретатора, который должен использоваться для подсветки цветом.
#
# python
#
# ```python
# a='Привет, мир!`
# print(a)
# ```
#
# javascript
#
# ```javascript
# var s = "Подсветка JavaScript";
# alert(s);
# ```

# %% [markdown]
# ## Ссылки
#
# Ссылки можно вставить разными способами.
#
# [Обычная ссылка в строке](https://www.google.com)
#
# [Обычная ссылка с title](https://www.google.com "Сайт Google")

# %% [markdown]
# ## Изображения
#
# Вот наш логотип (наведите указатель, чтобы увидеть текст заголовка):
#
# Внутри строки:
# ![alt-текст](https://raw.githubusercontent.com/dcurtis/markdown-mark/master/svg/markdown-mark.svg)
#
# Загрузка картинки в блокнот также возможна.
#
# ![%D0%9F%D1%80%D0%B8%D0%BC%D0%B5%D1%80.png](attachment:%D0%9F%D1%80%D0%B8%D0%BC%D0%B5%D1%80.png)

# %% [markdown]
# ## Таблицы
#
# Таблицы не являются частью Markdown, но многие обработчики, например Markdown Here и Github, поддерживают их.
#
# Вертикальные линии обозначают столбцы.
#
#
# | Таблицы       | Это                | Круто |
# | :------------- |:------------------:| -----:|
# | столбец 3     | выровнен вправо    | 1600 |
# | столбец 2     | выровнен по центру |   12 |
# | зебра-строки  | прикольные         |    1 |
#
# Внешние вертикальные линии (|) не обязательны и нужны только, чтобы сам код Markdown выглядел красиво. Тот же код можно записать так:
#
# Markdown | не такой | красивый
# --- | --- | ---
# *Но выводится* | `так же` | **клево**
# 1 | 2 | 3

# %% [markdown]
# Возможностей языка очень много. Дополнительно моно изучить, например, вот эту инструкцию https://gist.github.com/Jekins/2bf2d0638163f1294637
#
# ## Задание
#
# Измените тип ячейки и попробуйте создать примера элементов:
# - заголовок;
# - нумерованный список;
# - ненумерованный список;
# - выделение кода в тексте.
